# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-0b5f36u1
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-0b5f36u1
#   Resolved https://github.com/greydanus/mnist1d to commit 350929d12f4c9a4b7355e0c96604e41b9239bdb4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (2.31.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post9) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post9-py3-none-any.whl size=14496 sha256=b3cfea4c9d7320fff2da264174abc00aa66625fb791e4807558d75b9423d78c4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xaw1s4o_/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post9

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
# !mkdir ./sample_data

args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./sample_data/mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# mkdir: cannot create directory ‘./sample_data’: File exists
# Did or could not load data from ./sample_data/mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_o));


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions

# Define a model with two hidden layers of size 100 and ReLU activations between them
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),   # First hidden layer
    torch.nn.ReLU(),             # ReLU activation
    torch.nn.Linear(D_k, D_k),   # Second hidden layer
    torch.nn.ReLU(),             # ReLU activation
    torch.nn.Linear(D_k, D_o)    # Output layer
)

import torch.nn.init as init

def weights_init(layer):
    if isinstance(layer, torch.nn.Linear):
        init.kaiming_uniform_(layer.weight.data, mode='fan_in', nonlinearity='relu')
        init.zeros_(layer.bias.data)

# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.576560, train error 61.97,  test loss 1.667792, test error 68.50
# Epoch     1, train loss 1.331511, train error 48.67,  test loss 1.490311, test error 59.40
# Epoch     2, train loss 1.117032, train error 40.17,  test loss 1.307431, test error 50.00
# Epoch     3, train loss 0.973459, train error 34.80,  test loss 1.207475, test error 47.90
# Epoch     4, train loss 0.859483, train error 30.97,  test loss 1.171810, test error 47.80
# Epoch     5, train loss 0.792010, train error 28.57,  test loss 1.123823, test error 45.40
# Epoch     6, train loss 0.705609, train error 25.38,  test loss 1.143501, test error 43.80
# Epoch     7, train loss 0.624661, train error 21.22,  test loss 1.132390, test error 42.40
# Epoch     8, train loss 0.562272, train error 18.97,  test loss 1.126090, test error 41.50
# Epoch     9, train loss 0.544873, train error 18.32,  test loss 1.181769, test error 42.60
# Epoch    10, train loss 0.420740, train error 12.82,  test loss 1.074125, test error 39.50
# Epoch    11, train loss 0.382741, train error 11.10,  test loss 1.092969, test error 38.10
# Epoch    12, train loss 0.369045, train error 10.93,  test loss 1.161703, test error 40.50
# Epoch    13, train loss 0.329143, train error 9.47,  test loss 1.135878, test error 39.30
# Epoch    14, train loss 0.302908, train error 7.97,  test loss 1.160476, test error 39.30
# Epoch    15, train loss 0.280065, train error 6.93,  test loss 1.144445, test error 38.70
# Epoch    16, train loss 0.262912, train error 7.00,  test loss 1.211295, test error 38.90
# Epoch    17, train loss 0.231813, train error 5.28,  test loss 1.189556, test error 37.40
# Epoch    18, train loss 0.225976, train error 5.62,  test loss 1.214422, test error 37.30
# Epoch    19, train loss 0.196913, train error 4.43,  test loss 1.235541, test error 36.90
# Epoch    20, train loss 0.169698, train error 2.18,  test loss 1.224234, test error 37.30
# Epoch    21, train loss 0.161852, train error 2.53,  test loss 1.231926, test error 36.50
# Epoch    22, train loss 0.149490, train error 1.62,  test loss 1.255847, test error 37.90
# Epoch    23, train loss 0.139731, train error 1.28,  test loss 1.260876, test error 36.80
# Epoch    24, train loss 0.136077, train error 1.60,  test loss 1.274210, test error 36.80
# Epoch    25, train loss 0.128118, train error 1.05,  test loss 1.282093, test error 36.30
# Epoch    26, train loss 0.119052, train error 0.80,  test loss 1.305452, test error 36.70
# Epoch    27, train loss 0.113730, train error 0.57,  test loss 1.315207, test error 38.50
# Epoch    28, train loss 0.108642, train error 0.65,  test loss 1.337054, test error 37.60
# Epoch    29, train loss 0.106292, train error 0.62,  test loss 1.344443, test error 37.60
# Epoch    30, train loss 0.097665, train error 0.32,  test loss 1.344443, test error 37.10
# Epoch    31, train loss 0.095580, train error 0.22,  test loss 1.348127, test error 37.00
# Epoch    32, train loss 0.096041, train error 0.43,  test loss 1.356501, test error 36.50
# Epoch    33, train loss 0.091339, train error 0.28,  test loss 1.358269, test error 36.90
# Epoch    34, train loss 0.090260, train error 0.20,  test loss 1.379392, test error 38.10
# Epoch    35, train loss 0.086695, train error 0.20,  test loss 1.378493, test error 36.90
# Epoch    36, train loss 0.085308, train error 0.20,  test loss 1.388892, test error 37.30
# Epoch    37, train loss 0.083319, train error 0.22,  test loss 1.383306, test error 36.70
# Epoch    38, train loss 0.081111, train error 0.18,  test loss 1.392489, test error 36.90
# Epoch    39, train loss 0.079153, train error 0.07,  test loss 1.396194, test error 36.40
# Epoch    40, train loss 0.077833, train error 0.10,  test loss 1.402985, test error 37.30
# Epoch    41, train loss 0.076781, train error 0.10,  test loss 1.402887, test error 36.80
# Epoch    42, train loss 0.075967, train error 0.10,  test loss 1.408813, test error 36.80
# Epoch    43, train loss 0.075322, train error 0.07,  test loss 1.411743, test error 36.80
# Epoch    44, train loss 0.074457, train error 0.10,  test loss 1.416445, test error 37.00
# Epoch    45, train loss 0.073583, train error 0.07,  test loss 1.415132, test error 36.90
# Epoch    46, train loss 0.072651, train error 0.07,  test loss 1.419206, test error 36.70
# Epoch    47, train loss 0.072087, train error 0.07,  test loss 1.422155, test error 37.50
# Epoch    48, train loss 0.071366, train error 0.03,  test loss 1.425740, test error 36.80
# Epoch    49, train loss 0.070320, train error 0.05,  test loss 1.428025, test error 36.70

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions

# Define a model with four hidden layers of size 100 and ReLU activations between them
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),   # First hidden layer
    torch.nn.ReLU(),             # ReLU activation
    torch.nn.Linear(D_k, D_k),   # Second hidden layer
    torch.nn.ReLU(),             # ReLU activation
    torch.nn.Linear(D_k, D_k),   # Third hidden layer
    torch.nn.ReLU(),             # ReLU activation
    torch.nn.Linear(D_k, D_k),   # Fourth hidden layer
    torch.nn.ReLU(),             # ReLU activation
    torch.nn.Linear(D_k, D_o)    # Output layer
)

import torch.nn.init as init

def weights_init(layer):
    if isinstance(layer, torch.nn.Linear):
        init.kaiming_uniform_(layer.weight.data, mode='fan_in', nonlinearity='relu')
        init.zeros_(layer.bias.data)

# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=100, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.1, momentum=0.9)  #lr=0.05
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=50, shuffle=True, worker_init_fn=np.random.seed(1))   #batch_size=100

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 20
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.552274, train error 61.55,  test loss 1.589666, test error 66.10
# Epoch     1, train loss 1.391633, train error 56.40,  test loss 1.479388, test error 62.10
# Epoch     2, train loss 1.178232, train error 46.42,  test loss 1.312738, test error 53.40
# Epoch     3, train loss 1.303813, train error 50.75,  test loss 1.397942, test error 53.50
# Epoch     4, train loss 1.192185, train error 46.92,  test loss 1.459265, test error 55.20
# Epoch     5, train loss 1.058458, train error 40.97,  test loss 1.230808, test error 47.60
# Epoch     6, train loss 1.031579, train error 39.97,  test loss 1.252448, test error 47.80
# Epoch     7, train loss 0.977496, train error 38.15,  test loss 1.227557, test error 46.10
# Epoch     8, train loss 0.870981, train error 33.05,  test loss 1.118897, test error 42.30
# Epoch     9, train loss 0.900383, train error 32.55,  test loss 1.267519, test error 40.80
# Epoch    10, train loss 0.631928, train error 22.45,  test loss 1.210854, test error 38.10
# Epoch    11, train loss 0.451319, train error 16.30,  test loss 1.006091, test error 35.00
# Epoch    12, train loss 0.362526, train error 14.55,  test loss 1.067022, test error 33.70
# Epoch    13, train loss 0.407713, train error 16.53,  test loss 1.216091, test error 35.40
# Epoch    14, train loss 0.368633, train error 13.45,  test loss 1.151992, test error 35.40
# Epoch    15, train loss 0.292292, train error 11.40,  test loss 1.161434, test error 35.60
# Epoch    16, train loss 0.272139, train error 9.60,  test loss 1.256398, test error 35.60
# Epoch    17, train loss 0.309367, train error 11.60,  test loss 1.192118, test error 34.00
# Epoch    18, train loss 0.339186, train error 12.78,  test loss 1.203880, test error 35.10
# Epoch    19, train loss 0.294303, train error 11.18,  test loss 1.288123, test error 34.40

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()
