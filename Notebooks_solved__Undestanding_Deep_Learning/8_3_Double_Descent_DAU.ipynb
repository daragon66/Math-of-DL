# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-ixcsdmvg
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-ixcsdmvg
#   Resolved https://github.com/greydanus/mnist1d to commit 350929d12f4c9a4b7355e0c96604e41b9239bdb4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (2.31.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post9) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post9-py3-none-any.whl size=14496 sha256=b108663af1650bdc0efdeb349535722f3074e9082cb3613a80659effbd4dcd8c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_fyxbz5k/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post9

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
##1.
#Con 10 hidden_variables
##2.
#Con 60 hidden_variables
##3.
#Con 180 hidden_variables

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302489, train error 89.72,  test loss 2.302618, test error 90.30
# Epoch   100, train loss 2.302365, train error 89.65,  test loss 2.303053, test error 89.88
# Epoch   200, train loss 2.302354, train error 89.65,  test loss 2.302981, test error 89.88
# Epoch   300, train loss 2.302359, train error 89.65,  test loss 2.302933, test error 89.88
# Epoch   400, train loss 2.302356, train error 89.65,  test loss 2.302973, test error 89.88
# Epoch   500, train loss 2.302358, train error 89.65,  test loss 2.302935, test error 89.88
# Epoch   600, train loss 2.302354, train error 89.72,  test loss 2.302963, test error 90.30
# Epoch   700, train loss 2.302356, train error 89.65,  test loss 2.303002, test error 89.88
# Epoch   800, train loss 2.302355, train error 89.72,  test loss 2.302971, test error 90.30
# Epoch   900, train loss 2.302363, train error 89.72,  test loss 2.302924, test error 90.30
# Training model with   4 hidden variables
# Epoch     0, train loss 2.280119, train error 89.35,  test loss 2.271920, test error 87.18
# Epoch   100, train loss 1.753027, train error 63.72,  test loss 1.573284, test error 59.97
# Epoch   200, train loss 1.734084, train error 62.88,  test loss 1.539504, test error 59.65
# Epoch   300, train loss 1.730397, train error 62.25,  test loss 1.543320, test error 59.70
# Epoch   400, train loss 1.725787, train error 62.42,  test loss 1.528093, test error 58.42
# Epoch   500, train loss 1.721537, train error 61.95,  test loss 1.517772, test error 58.80
# Epoch   600, train loss 1.718372, train error 61.62,  test loss 1.520321, test error 58.67
# Epoch   700, train loss 1.718305, train error 61.97,  test loss 1.514040, test error 59.00
# Epoch   800, train loss 1.717332, train error 62.47,  test loss 1.518944, test error 58.28
# Epoch   900, train loss 1.721883, train error 62.25,  test loss 1.519823, test error 58.62
# Training model with   6 hidden variables
# Epoch     0, train loss 2.281762, train error 85.10,  test loss 2.278924, test error 84.65
# Epoch   100, train loss 1.705281, train error 62.92,  test loss 1.561570, test error 60.67
# Epoch   200, train loss 1.691216, train error 62.55,  test loss 1.564916, test error 61.10
# Epoch   300, train loss 1.672298, train error 60.10,  test loss 1.563394, test error 60.30
# Epoch   400, train loss 1.655393, train error 59.05,  test loss 1.550267, test error 59.25
# Epoch   500, train loss 1.650908, train error 59.30,  test loss 1.545205, test error 59.55
# Epoch   600, train loss 1.649433, train error 59.35,  test loss 1.557979, test error 60.65
# Epoch   700, train loss 1.651368, train error 59.35,  test loss 1.554366, test error 60.35
# Epoch   800, train loss 1.651201, train error 58.83,  test loss 1.555655, test error 59.55
# Epoch   900, train loss 1.645975, train error 59.10,  test loss 1.549175, test error 59.85
# Training model with   8 hidden variables
# Epoch     0, train loss 2.287049, train error 85.82,  test loss 2.291361, test error 86.78
# Epoch   100, train loss 1.605963, train error 55.83,  test loss 1.426566, test error 53.88
# Epoch   200, train loss 1.559553, train error 54.15,  test loss 1.412667, test error 53.58
# Epoch   300, train loss 1.548601, train error 53.85,  test loss 1.419269, test error 53.42
# Epoch   400, train loss 1.540921, train error 52.95,  test loss 1.433552, test error 53.55
# Epoch   500, train loss 1.538384, train error 53.20,  test loss 1.434179, test error 54.00
# Epoch   600, train loss 1.534347, train error 53.03,  test loss 1.447556, test error 53.85
# Epoch   700, train loss 1.531205, train error 52.60,  test loss 1.453184, test error 54.00
# Epoch   800, train loss 1.531822, train error 52.65,  test loss 1.458734, test error 53.88
# Epoch   900, train loss 1.524333, train error 52.28,  test loss 1.457413, test error 54.33
# Training model with  10 hidden variables
# Epoch     0, train loss 2.259874, train error 84.60,  test loss 2.239383, test error 83.43
# Epoch   100, train loss 1.540701, train error 53.40,  test loss 1.363702, test error 51.70
# Epoch   200, train loss 1.457356, train error 49.22,  test loss 1.283054, test error 47.15
# Epoch   300, train loss 1.432447, train error 49.10,  test loss 1.287630, test error 47.95
# Epoch   400, train loss 1.412411, train error 47.60,  test loss 1.287635, test error 47.22
# Epoch   500, train loss 1.392818, train error 46.75,  test loss 1.253082, test error 46.42
# Epoch   600, train loss 1.379317, train error 46.53,  test loss 1.256066, test error 46.12
# Epoch   700, train loss 1.363641, train error 46.70,  test loss 1.259547, test error 46.00
# Epoch   800, train loss 1.355959, train error 45.75,  test loss 1.259416, test error 45.70
# Epoch   900, train loss 1.356352, train error 45.42,  test loss 1.262485, test error 46.17
# Training model with  14 hidden variables
# Epoch     0, train loss 2.294074, train error 86.80,  test loss 2.305704, test error 87.85
# Epoch   100, train loss 1.407847, train error 46.10,  test loss 1.257146, test error 46.80
# Epoch   200, train loss 1.324487, train error 44.05,  test loss 1.245751, test error 46.25
# Epoch   300, train loss 1.294008, train error 42.22,  test loss 1.293618, test error 47.90
# Epoch   400, train loss 1.274040, train error 41.35,  test loss 1.297234, test error 47.60
# Epoch   500, train loss 1.266095, train error 41.00,  test loss 1.304972, test error 48.00
# Epoch   600, train loss 1.254965, train error 41.12,  test loss 1.308856, test error 48.15
# Epoch   700, train loss 1.248443, train error 41.58,  test loss 1.324841, test error 48.42
# Epoch   800, train loss 1.235114, train error 40.40,  test loss 1.342655, test error 48.38
# Epoch   900, train loss 1.232620, train error 39.85,  test loss 1.353960, test error 48.30
# Training model with  18 hidden variables
# Epoch     0, train loss 2.126037, train error 80.07,  test loss 2.066730, test error 79.00
# Epoch   100, train loss 1.395453, train error 48.08,  test loss 1.395677, test error 52.67
# Epoch   200, train loss 1.301710, train error 44.22,  test loss 1.410975, test error 51.58
# Epoch   300, train loss 1.243546, train error 42.22,  test loss 1.433800, test error 51.15
# Epoch   400, train loss 1.205719, train error 40.62,  test loss 1.438526, test error 51.22
# Epoch   500, train loss 1.181237, train error 40.30,  test loss 1.464961, test error 51.95
# Epoch   600, train loss 1.162144, train error 39.80,  test loss 1.511671, test error 52.38
# Epoch   700, train loss 1.141843, train error 39.00,  test loss 1.538408, test error 52.20
# Epoch   800, train loss 1.124743, train error 38.12,  test loss 1.583468, test error 53.05
# Epoch   900, train loss 1.125182, train error 37.88,  test loss 1.613624, test error 52.78
# Training model with  22 hidden variables
# Epoch     0, train loss 2.211709, train error 82.68,  test loss 2.187942, test error 81.70
# Epoch   100, train loss 1.313316, train error 43.88,  test loss 1.343837, test error 50.15
# Epoch   200, train loss 1.166870, train error 38.55,  test loss 1.374604, test error 49.03
# Epoch   300, train loss 1.088808, train error 36.35,  test loss 1.423756, test error 49.65
# Epoch   400, train loss 1.054764, train error 35.05,  test loss 1.486975, test error 50.08
# Epoch   500, train loss 1.038738, train error 34.78,  test loss 1.531593, test error 50.62
# Epoch   600, train loss 1.011033, train error 33.68,  test loss 1.601829, test error 52.45
# Epoch   700, train loss 1.000993, train error 33.53,  test loss 1.626418, test error 52.20
# Epoch   800, train loss 0.986214, train error 33.68,  test loss 1.660473, test error 52.53
# Epoch   900, train loss 0.998146, train error 33.80,  test loss 1.732560, test error 53.00
# Training model with  26 hidden variables
# Epoch     0, train loss 2.184948, train error 80.53,  test loss 2.183973, test error 81.05
# Epoch   100, train loss 1.213037, train error 40.60,  test loss 1.333568, test error 49.72
# Epoch   200, train loss 1.069721, train error 35.18,  test loss 1.400654, test error 49.58
# Epoch   300, train loss 0.990524, train error 33.07,  test loss 1.486843, test error 50.47
# Epoch   400, train loss 0.948872, train error 31.25,  test loss 1.564361, test error 51.40
# Epoch   500, train loss 0.927553, train error 30.82,  test loss 1.632408, test error 51.97
# Epoch   600, train loss 0.911086, train error 30.60,  test loss 1.678623, test error 52.50
# Epoch   700, train loss 0.901504, train error 30.35,  test loss 1.703396, test error 52.17
# Epoch   800, train loss 0.879047, train error 29.20,  test loss 1.763397, test error 52.35
# Epoch   900, train loss 0.879824, train error 30.20,  test loss 1.808332, test error 52.78
# Training model with  30 hidden variables
# Epoch     0, train loss 2.092184, train error 77.62,  test loss 2.042917, test error 75.45
# Epoch   100, train loss 1.100571, train error 36.67,  test loss 1.373484, test error 49.90
# Epoch   200, train loss 0.926628, train error 31.70,  test loss 1.590133, test error 51.10
# Epoch   300, train loss 0.824241, train error 28.03,  test loss 1.806949, test error 52.17
# Epoch   400, train loss 0.801051, train error 27.15,  test loss 1.996923, test error 54.00
# Epoch   500, train loss 0.740429, train error 24.90,  test loss 2.132303, test error 54.45
# Epoch   600, train loss 0.713857, train error 24.80,  test loss 2.283508, test error 54.53
# Epoch   700, train loss 0.697645, train error 24.28,  test loss 2.453362, test error 54.78
# Epoch   800, train loss 0.673926, train error 23.07,  test loss 2.595297, test error 55.58
# Epoch   900, train loss 0.656479, train error 22.30,  test loss 2.692172, test error 55.58
# Training model with  35 hidden variables
# Epoch     0, train loss 2.155969, train error 80.80,  test loss 2.143326, test error 80.22
# Epoch   100, train loss 1.044031, train error 33.95,  test loss 1.372886, test error 49.65
# Epoch   200, train loss 0.835296, train error 27.80,  test loss 1.651948, test error 50.75
# Epoch   300, train loss 0.717718, train error 24.70,  test loss 1.941540, test error 51.70
# Epoch   400, train loss 0.617960, train error 20.40,  test loss 2.333400, test error 54.10
# Epoch   500, train loss 0.561162, train error 18.88,  test loss 2.580078, test error 53.42
# Epoch   600, train loss 0.504682, train error 16.97,  test loss 2.887900, test error 53.53
# Epoch   700, train loss 0.508449, train error 17.30,  test loss 3.177257, test error 54.58
# Epoch   800, train loss 0.500492, train error 17.72,  test loss 3.448933, test error 53.90
# Epoch   900, train loss 0.455181, train error 16.43,  test loss 3.705094, test error 54.33
# Training model with  40 hidden variables
# Epoch     0, train loss 2.076122, train error 76.43,  test loss 2.010087, test error 75.38
# Epoch   100, train loss 0.907373, train error 28.93,  test loss 1.510843, test error 52.20
# Epoch   200, train loss 0.642459, train error 20.80,  test loss 2.025355, test error 54.53
# Epoch   300, train loss 0.537974, train error 17.75,  test loss 2.654842, test error 56.30
# Epoch   400, train loss 0.461592, train error 15.95,  test loss 3.263971, test error 56.83
# Epoch   500, train loss 0.396690, train error 13.20,  test loss 3.885220, test error 57.72
# Epoch   600, train loss 0.309687, train error 9.97,  test loss 4.460947, test error 57.35
# Epoch   700, train loss 0.326126, train error 11.80,  test loss 5.165488, test error 57.50
# Epoch   800, train loss 0.306164, train error 11.32,  test loss 5.611380, test error 57.12
# Epoch   900, train loss 0.291098, train error 10.75,  test loss 6.169280, test error 57.38
# Training model with  45 hidden variables
# Epoch     0, train loss 2.108987, train error 78.20,  test loss 2.068613, test error 78.38
# Epoch   100, train loss 0.781262, train error 24.88,  test loss 1.487398, test error 49.03
# Epoch   200, train loss 0.470498, train error 15.65,  test loss 2.158144, test error 51.75
# Epoch   300, train loss 0.312555, train error 10.25,  test loss 3.134298, test error 53.30
# Epoch   400, train loss 0.248724, train error 8.38,  test loss 4.386731, test error 55.58
# Epoch   500, train loss 0.151559, train error 5.28,  test loss 5.460071, test error 54.05
# Epoch   600, train loss 0.109252, train error 3.43,  test loss 6.751914, test error 55.17
# Epoch   700, train loss 0.013810, train error 0.00,  test loss 7.746534, test error 54.90
# Epoch   800, train loss 0.007017, train error 0.00,  test loss 8.406192, test error 54.58
# Epoch   900, train loss 0.005145, train error 0.00,  test loss 8.863778, test error 54.53
# Training model with  50 hidden variables
# Epoch     0, train loss 2.102465, train error 77.30,  test loss 2.052374, test error 76.35
# Epoch   100, train loss 0.723061, train error 23.00,  test loss 1.586409, test error 49.22
# Epoch   200, train loss 0.361889, train error 10.55,  test loss 2.657027, test error 53.22
# Epoch   300, train loss 0.160745, train error 4.12,  test loss 4.161054, test error 55.72
# Epoch   400, train loss 0.033333, train error 0.05,  test loss 5.826989, test error 56.15
# Epoch   500, train loss 0.013685, train error 0.00,  test loss 6.881416, test error 56.40
# Epoch   600, train loss 0.008688, train error 0.00,  test loss 7.534392, test error 56.35
# Epoch   700, train loss 0.006194, train error 0.00,  test loss 8.041818, test error 56.60
# Epoch   800, train loss 0.004746, train error 0.00,  test loss 8.437186, test error 56.78
# Epoch   900, train loss 0.003806, train error 0.00,  test loss 8.767673, test error 56.65
# Training model with  55 hidden variables
# Epoch     0, train loss 2.034829, train error 77.30,  test loss 1.954600, test error 76.90
# Epoch   100, train loss 0.627601, train error 19.32,  test loss 1.558666, test error 49.83
# Epoch   200, train loss 0.262111, train error 7.45,  test loss 2.888474, test error 53.72
# Epoch   300, train loss 0.041314, train error 0.05,  test loss 4.381318, test error 53.35
# Epoch   400, train loss 0.015054, train error 0.00,  test loss 5.358942, test error 53.05
# Epoch   500, train loss 0.008324, train error 0.00,  test loss 5.943940, test error 53.30
# Epoch   600, train loss 0.005751, train error 0.00,  test loss 6.370946, test error 53.55
# Epoch   700, train loss 0.004250, train error 0.00,  test loss 6.693015, test error 53.75
# Epoch   800, train loss 0.003363, train error 0.00,  test loss 6.955502, test error 53.83
# Epoch   900, train loss 0.002768, train error 0.00,  test loss 7.178855, test error 53.67
# Training model with  60 hidden variables
# Epoch     0, train loss 2.015263, train error 75.18,  test loss 1.931847, test error 74.40
# Epoch   100, train loss 0.525036, train error 15.47,  test loss 1.843377, test error 53.67
# Epoch   200, train loss 0.110958, train error 1.45,  test loss 3.436278, test error 55.08
# Epoch   300, train loss 0.018824, train error 0.00,  test loss 4.707352, test error 54.85
# Epoch   400, train loss 0.008920, train error 0.00,  test loss 5.365105, test error 54.85
# Epoch   500, train loss 0.005677, train error 0.00,  test loss 5.801507, test error 55.08
# Epoch   600, train loss 0.004083, train error 0.00,  test loss 6.120325, test error 54.85
# Epoch   700, train loss 0.003158, train error 0.00,  test loss 6.379528, test error 54.83
# Epoch   800, train loss 0.002541, train error 0.00,  test loss 6.587290, test error 54.80
# Epoch   900, train loss 0.002112, train error 0.00,  test loss 6.768833, test error 54.95
# Training model with  70 hidden variables
# Epoch     0, train loss 2.048706, train error 76.10,  test loss 1.997943, test error 77.55
# Epoch   100, train loss 0.355860, train error 9.00,  test loss 1.915300, test error 51.28
# Epoch   200, train loss 0.032887, train error 0.00,  test loss 3.561228, test error 54.28
# Epoch   300, train loss 0.011038, train error 0.00,  test loss 4.337998, test error 54.08
# Epoch   400, train loss 0.006190, train error 0.00,  test loss 4.779607, test error 54.00
# Epoch   500, train loss 0.004157, train error 0.00,  test loss 5.087986, test error 53.85
# Epoch   600, train loss 0.003061, train error 0.00,  test loss 5.318404, test error 53.83
# Epoch   700, train loss 0.002403, train error 0.00,  test loss 5.506091, test error 53.85
# Epoch   800, train loss 0.001960, train error 0.00,  test loss 5.661765, test error 53.80
# Epoch   900, train loss 0.001647, train error 0.00,  test loss 5.795524, test error 53.72
# Training model with  80 hidden variables
# Epoch     0, train loss 1.987577, train error 73.97,  test loss 1.908668, test error 73.93
# Epoch   100, train loss 0.221559, train error 4.05,  test loss 2.214906, test error 53.42
# Epoch   200, train loss 0.019381, train error 0.00,  test loss 3.519942, test error 53.92
# Epoch   300, train loss 0.007913, train error 0.00,  test loss 4.080730, test error 53.95
# Epoch   400, train loss 0.004728, train error 0.00,  test loss 4.421189, test error 54.08
# Epoch   500, train loss 0.003247, train error 0.00,  test loss 4.661439, test error 53.97
# Epoch   600, train loss 0.002447, train error 0.00,  test loss 4.844123, test error 53.92
# Epoch   700, train loss 0.001946, train error 0.00,  test loss 4.996205, test error 54.08
# Epoch   800, train loss 0.001605, train error 0.00,  test loss 5.126564, test error 54.08
# Epoch   900, train loss 0.001358, train error 0.00,  test loss 5.236552, test error 54.12
# Training model with  90 hidden variables
# Epoch     0, train loss 1.989705, train error 73.93,  test loss 1.914761, test error 74.43
# Epoch   100, train loss 0.151869, train error 1.45,  test loss 2.142003, test error 51.42
# Epoch   200, train loss 0.015429, train error 0.00,  test loss 3.175003, test error 51.67
# Epoch   300, train loss 0.006748, train error 0.00,  test loss 3.615670, test error 52.08
# Epoch   400, train loss 0.004086, train error 0.00,  test loss 3.879534, test error 52.42
# Epoch   500, train loss 0.002867, train error 0.00,  test loss 4.074557, test error 52.35
# Epoch   600, train loss 0.002176, train error 0.00,  test loss 4.220566, test error 52.40
# Epoch   700, train loss 0.001738, train error 0.00,  test loss 4.343407, test error 52.35
# Epoch   800, train loss 0.001438, train error 0.00,  test loss 4.446248, test error 52.35
# Epoch   900, train loss 0.001220, train error 0.00,  test loss 4.534835, test error 52.53
# Training model with 100 hidden variables
# Epoch     0, train loss 1.989560, train error 74.60,  test loss 1.911229, test error 73.57
# Epoch   100, train loss 0.085318, train error 0.22,  test loss 2.242861, test error 51.10
# Epoch   200, train loss 0.012111, train error 0.00,  test loss 3.069509, test error 51.45
# Epoch   300, train loss 0.005690, train error 0.00,  test loss 3.425930, test error 51.45
# Epoch   400, train loss 0.003573, train error 0.00,  test loss 3.649945, test error 51.58
# Epoch   500, train loss 0.002532, train error 0.00,  test loss 3.812220, test error 51.58
# Epoch   600, train loss 0.001939, train error 0.00,  test loss 3.941593, test error 51.53
# Epoch   700, train loss 0.001559, train error 0.00,  test loss 4.047194, test error 51.55
# Epoch   800, train loss 0.001296, train error 0.00,  test loss 4.135816, test error 51.53
# Epoch   900, train loss 0.001104, train error 0.00,  test loss 4.214279, test error 51.62
# Training model with 120 hidden variables
# Epoch     0, train loss 2.003577, train error 75.47,  test loss 1.936056, test error 76.30
# Epoch   100, train loss 0.054793, train error 0.00,  test loss 2.263960, test error 51.65
# Epoch   200, train loss 0.009743, train error 0.00,  test loss 2.898988, test error 51.53
# Epoch   300, train loss 0.004805, train error 0.00,  test loss 3.185427, test error 51.62
# Epoch   400, train loss 0.003068, train error 0.00,  test loss 3.370796, test error 51.55
# Epoch   500, train loss 0.002204, train error 0.00,  test loss 3.508068, test error 51.70
# Epoch   600, train loss 0.001702, train error 0.00,  test loss 3.615881, test error 51.92
# Epoch   700, train loss 0.001375, train error 0.00,  test loss 3.706283, test error 51.95
# Epoch   800, train loss 0.001148, train error 0.00,  test loss 3.782701, test error 51.95
# Epoch   900, train loss 0.000981, train error 0.00,  test loss 3.849905, test error 51.97
# Training model with 140 hidden variables
# Epoch     0, train loss 1.952262, train error 72.95,  test loss 1.871181, test error 72.32
# Epoch   100, train loss 0.033959, train error 0.00,  test loss 2.115225, test error 47.97
# Epoch   200, train loss 0.007974, train error 0.00,  test loss 2.568022, test error 48.55
# Epoch   300, train loss 0.004118, train error 0.00,  test loss 2.789477, test error 48.62
# Epoch   400, train loss 0.002686, train error 0.00,  test loss 2.930869, test error 48.60
# Epoch   500, train loss 0.001957, train error 0.00,  test loss 3.039247, test error 48.47
# Epoch   600, train loss 0.001523, train error 0.00,  test loss 3.124255, test error 48.58
# Epoch   700, train loss 0.001238, train error 0.00,  test loss 3.195437, test error 48.60
# Epoch   800, train loss 0.001037, train error 0.00,  test loss 3.256813, test error 48.62
# Epoch   900, train loss 0.000889, train error 0.00,  test loss 3.310416, test error 48.58
# Training model with 160 hidden variables
# Epoch     0, train loss 1.934005, train error 71.43,  test loss 1.848858, test error 71.55
# Epoch   100, train loss 0.028289, train error 0.00,  test loss 2.052285, test error 48.05
# Epoch   200, train loss 0.007203, train error 0.00,  test loss 2.445280, test error 47.95
# Epoch   300, train loss 0.003775, train error 0.00,  test loss 2.638419, test error 47.97
# Epoch   400, train loss 0.002482, train error 0.00,  test loss 2.767345, test error 47.83
# Epoch   500, train loss 0.001818, train error 0.00,  test loss 2.863230, test error 47.80
# Epoch   600, train loss 0.001421, train error 0.00,  test loss 2.939578, test error 47.75
# Epoch   700, train loss 0.001157, train error 0.00,  test loss 3.003584, test error 47.88
# Epoch   800, train loss 0.000971, train error 0.00,  test loss 3.058470, test error 47.88
# Epoch   900, train loss 0.000833, train error 0.00,  test loss 3.105820, test error 47.85
# Training model with 180 hidden variables
# Epoch     0, train loss 1.934179, train error 70.65,  test loss 1.874528, test error 72.38
# Epoch   100, train loss 0.024437, train error 0.00,  test loss 2.056922, test error 48.65
# Epoch   200, train loss 0.006649, train error 0.00,  test loss 2.419547, test error 48.95
# Epoch   300, train loss 0.003556, train error 0.00,  test loss 2.599260, test error 48.72
# Epoch   400, train loss 0.002357, train error 0.00,  test loss 2.722617, test error 48.70
# Epoch   500, train loss 0.001734, train error 0.00,  test loss 2.812828, test error 48.65
# Epoch   600, train loss 0.001359, train error 0.00,  test loss 2.886410, test error 48.75
# Epoch   700, train loss 0.001109, train error 0.00,  test loss 2.946859, test error 48.67
# Epoch   800, train loss 0.000933, train error 0.00,  test loss 2.998924, test error 48.62
# Epoch   900, train loss 0.000802, train error 0.00,  test loss 3.044669, test error 48.70
# Training model with 200 hidden variables
# Epoch     0, train loss 1.929595, train error 70.72,  test loss 1.849876, test error 72.05
# Epoch   100, train loss 0.021337, train error 0.00,  test loss 2.021411, test error 48.22
# Epoch   200, train loss 0.006068, train error 0.00,  test loss 2.330529, test error 47.88
# Epoch   300, train loss 0.003294, train error 0.00,  test loss 2.491111, test error 47.75
# Epoch   400, train loss 0.002199, train error 0.00,  test loss 2.600881, test error 47.67
# Epoch   500, train loss 0.001625, train error 0.00,  test loss 2.682738, test error 47.55
# Epoch   600, train loss 0.001277, train error 0.00,  test loss 2.749469, test error 47.62
# Epoch   700, train loss 0.001045, train error 0.00,  test loss 2.804607, test error 47.62
# Epoch   800, train loss 0.000880, train error 0.00,  test loss 2.852238, test error 47.53
# Epoch   900, train loss 0.000757, train error 0.00,  test loss 2.893723, test error 47.47
# Training model with 250 hidden variables
# Epoch     0, train loss 1.894832, train error 69.68,  test loss 1.830702, test error 70.97
# Epoch   100, train loss 0.017225, train error 0.00,  test loss 1.928292, test error 47.72
# Epoch   200, train loss 0.005386, train error 0.00,  test loss 2.182032, test error 47.53
# Epoch   300, train loss 0.002995, train error 0.00,  test loss 2.315080, test error 47.30
# Epoch   400, train loss 0.002020, train error 0.00,  test loss 2.406891, test error 47.35
# Epoch   500, train loss 0.001503, train error 0.00,  test loss 2.475465, test error 47.20
# Epoch   600, train loss 0.001186, train error 0.00,  test loss 2.531463, test error 47.20
# Epoch   700, train loss 0.000973, train error 0.00,  test loss 2.578356, test error 47.12
# Epoch   800, train loss 0.000821, train error 0.00,  test loss 2.619084, test error 47.22
# Epoch   900, train loss 0.000708, train error 0.00,  test loss 2.654374, test error 47.20
# Training model with 300 hidden variables
# Epoch     0, train loss 1.873508, train error 66.90,  test loss 1.828657, test error 70.88
# Epoch   100, train loss 0.014214, train error 0.00,  test loss 1.885596, test error 47.17
# Epoch   200, train loss 0.004753, train error 0.00,  test loss 2.111320, test error 46.95
# Epoch   300, train loss 0.002695, train error 0.00,  test loss 2.233377, test error 46.67
# Epoch   400, train loss 0.001836, train error 0.00,  test loss 2.317260, test error 46.72
# Epoch   500, train loss 0.001374, train error 0.00,  test loss 2.380271, test error 46.70
# Epoch   600, train loss 0.001089, train error 0.00,  test loss 2.431629, test error 46.62
# Epoch   700, train loss 0.000896, train error 0.00,  test loss 2.475366, test error 46.65
# Epoch   800, train loss 0.000759, train error 0.00,  test loss 2.512165, test error 46.67
# Epoch   900, train loss 0.000656, train error 0.00,  test loss 2.544618, test error 46.70
# Training model with 400 hidden variables
# Epoch     0, train loss 1.826493, train error 64.75,  test loss 1.757999, test error 67.85
# Epoch   100, train loss 0.011538, train error 0.00,  test loss 1.768051, test error 46.12
# Epoch   200, train loss 0.004108, train error 0.00,  test loss 1.945283, test error 46.05
# Epoch   300, train loss 0.002381, train error 0.00,  test loss 2.041162, test error 46.00
# Epoch   400, train loss 0.001641, train error 0.00,  test loss 2.110054, test error 45.97
# Epoch   500, train loss 0.001236, train error 0.00,  test loss 2.162510, test error 46.03
# Epoch   600, train loss 0.000985, train error 0.00,  test loss 2.204866, test error 45.88
# Epoch   700, train loss 0.000814, train error 0.00,  test loss 2.240576, test error 45.85
# Epoch   800, train loss 0.000691, train error 0.00,  test loss 2.271655, test error 45.70
# Epoch   900, train loss 0.000599, train error 0.00,  test loss 2.298369, test error 45.72

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
